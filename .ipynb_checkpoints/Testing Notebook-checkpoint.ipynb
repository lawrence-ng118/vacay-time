# %%
import requests
import time
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
from selenium.webdriver.common.actions.action_builder import ActionBuilder
from selenium.webdriver.common.actions.mouse_button import MouseButton

# open driver
driver = webdriver.Chrome()

# load google search bar XD
driver.get("https://www.google.com/")

#  locating search bar
search_bar = driver.find_element(By.CLASS_NAME, "gLFyf")

# getting the user inputs
og_currency = input("Please input your original currency: ")
currencies = ["JPY"]

# going thru all the exchange rates
# actions = ActionChains(driver)
for i in currencies:
    # enter search entry
    search_bar.send_keys(og_currency + " TO " + i)
    time.sleep(1)
    search_bar.send_keys(Keys.RETURN)
    time.sleep(2)

    # go to google finance page
    driver.find_element(By.CLASS_NAME, "jRKCUd").click()
    time.sleep(3)
    
    # go to history tab (1D, 5D, 1M, 1Y, 5Y, Max)
    driver.find_element(By.ID, "5yearTab").click()
    
    # hover thru the time graph (CURRENT PROBLEM, DONT KNOW HOW TO HOVER THRU AND GET THE DATA)
    driver.find_element(By.CLASS_NAME, "hSGhwc").moveToElement()
    date = driver.find_element(By.CLASS_NAME, "knowledge-finance-wholepage-chart__hover-card-time")
    value = driver.find_element(By.CLASS_NAME, "knowledge-finance-wholepage-chart__hover-card-value")
    
    driver.back()
# Out:
# Please input your original currency:  PHP
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[31], line 41
#      38 driver.find_element(By.ID, "5yearTab").click()
#      40 # hover thru the time graph
# ---> 41 driver.find_element(By.CLASS_NAME, "hSGhwc").moveToElement()
#      42 date = driver.find_element(By.CLASS_NAME, "knowledge-finance-wholepage-chart__hover-card-time")
#      43 value = driver.find_element(By.CLASS_NAME, "knowledge-finance-wholepage-chart__hover-card-value")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\selenium\webdriver\remote\webdriver.py:748, in WebDriver.find_element(self, by, value)
#     745     by = By.CSS_SELECTOR
#     746     value = f'[name="{value}"]'
# --> 748 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File ~\AppData\Roaming\Python\Python311\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".hSGhwc"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF61C0DEEA2+31554]
# 	(No symbol) [0x00007FF61C057ED9]
# 	(No symbol) [0x00007FF61BF1872A]
# 	(No symbol) [0x00007FF61BF68434]
# 	(No symbol) [0x00007FF61BF6853C]
# 	(No symbol) [0x00007FF61BFAF6A7]
# 	(No symbol) [0x00007FF61BF8D06F]
# 	(No symbol) [0x00007FF61BFAC977]
# 	(No symbol) [0x00007FF61BF8CDD3]
# 	(No symbol) [0x00007FF61BF5A33B]
# 	(No symbol) [0x00007FF61BF5AED1]
# 	GetHandleVerifier [0x00007FF61C3E8B1D+3217341]
# 	GetHandleVerifier [0x00007FF61C435AE3+3532675]
# 	GetHandleVerifier [0x00007FF61C42B0E0+3489152]
# 	GetHandleVerifier [0x00007FF61C18E776+750614]
# 	(No symbol) [0x00007FF61C06375F]
# 	(No symbol) [0x00007FF61C05EB14]
# 	(No symbol) [0x00007FF61C05ECA2]
# 	(No symbol) [0x00007FF61C04E16F]
# 	BaseThreadInitThunk [0x00007FFBF2DC257D+29]
# 	RtlUserThreadStart [0x00007FFBF4EAAF28+40]

# %%
import requests
import time
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
from selenium.webdriver.common.actions.action_builder import ActionBuilder
from selenium.webdriver.common.actions.mouse_button import MouseButton
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import re
from datetime import date
currentdate = date.today()
current_year = int(currentdate.year)

# getting the user inputs
from_currency = input("Please input your original currency: ")
currencies = ["JPY"]
how_many_years_back = int(input("How many years back do you want to consider the data of? "))
exchange_rates = {}

# open driver
driver = webdriver.Chrome()

# going thru all the exchange rates
for i in currencies:
    # load website
    history = []
    for j in range(0, how_many_years_back+1):
        link = f"https://www.exchange-rates.org/exchange-rate-history/{from_currency}-{i}-{current_year-j}"
        print(link)
        response = requests.get(link)
    
        soup = BeautifulSoup(response.text, 'html.parser')

        date_data = soup.find_all('a', class_="n")
        rate_data = soup.find_all('span', class_="n")
        print(date_data)
        print(rate_data)
        for number in range(0, len(date_data)):
            date = (str(date_data[number]))[(str(date_data[number])).index(">")+1:(str(date_data[number])).index("</a>")]
            rate = str(rate_data[number])
            rate = rate.replace('<span class="n">', '')
            rate = rate.replace('<span class="nowrap">', '')
            rate = rate.replace('</span>', '')
            entry = date + " | " + rate
            history.append(entry)
    exchange_rates[i] = history

print(exchange_rates)
# Out:
# Please input your original currency:  php
# How many years back do you want to consider the data of?  1
# https://www.exchange-rates.org/exchange-rate-history/php-JPY-2024
# []
# [<span class="n">2024-1-1</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.5441 JPY</span></span>, <span class="n">2024-1-2</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.5568 JPY</span></span>, <span class="n">2024-1-3</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.5676 JPY</span></span>, <span class="n">2024-1-4</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.6051 JPY</span></span>, <span class="n">2024-1-5</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.6058 JPY</span></span>, <span class="n">2024-1-8</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.5858 JPY</span></span>, <span class="n">2024-1-9</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.5724 JPY</span></span>, <span class="n">2024-1-10</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.5936 JPY</span></span>, <span class="n">2024-1-11</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.5888 JPY</span></span>, <span class="n">2024-1-12</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.5958 JPY</span></span>, <span class="n">2024-1-15</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.6163 JPY</span></span>, <span class="n">2024-1-16</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.6296 JPY</span></span>, <span class="n">2024-1-17</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.6465 JPY</span></span>, <span class="n">2024-1-18</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.6536 JPY</span></span>, <span class="n">2024-1-19</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.6507 JPY</span></span>, <span class="n">2024-1-22</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.6276 JPY</span></span>, <span class="n">2024-1-23</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.6294 JPY</span></span>, <span class="n">2024-1-24</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.6224 JPY</span></span>, <span class="n">2024-1-25</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.6094 JPY</span></span>, <span class="n">2024-1-26</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.6311 JPY</span></span>, <span class="n">2024-1-29</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.6143 JPY</span></span>, <span class="n">2024-1-30</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.6185 JPY</span></span>, <span class="n">2024-1-31</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.6095 JPY</span></span>, <span class="n">2024-2-1</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.6151 JPY</span></span>, <span class="n">2024-2-2</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.6418 JPY</span></span>, <span class="n">2024-2-5</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.6369 JPY</span></span>, <span class="n">2024-2-6</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.6323 JPY</span></span>, <span class="n">2024-2-7</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.6415 JPY</span></span>, <span class="n">2024-2-8</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.6666 JPY</span></span>, <span class="n">2024-2-9</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.6712 JPY</span></span>, <span class="n">2024-2- ...
# https://www.exchange-rates.org/exchange-rate-history/php-JPY-2023
# []
# [<span class="n">2023-1-2</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.3460 JPY</span></span>, <span class="n">2023-1-3</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.3412 JPY</span></span>, <span class="n">2023-1-4</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.3661 JPY</span></span>, <span class="n">2023-1-5</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.3897 JPY</span></span>, <span class="n">2023-1-6</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.3910 JPY</span></span>, <span class="n">2023-1-9</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.4080 JPY</span></span>, <span class="n">2023-1-10</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.4130 JPY</span></span>, <span class="n">2023-1-11</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.4063 JPY</span></span>, <span class="n">2023-1-12</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.3495 JPY</span></span>, <span class="n">2023-1-13</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.3311 JPY</span></span>, <span class="n">2023-1-16</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.3532 JPY</span></span>, <span class="n">2023-1-17</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.3458 JPY</span></span>, <span class="n">2023-1-18</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.3542 JPY</span></span>, <span class="n">2023-1-19</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.3465 JPY</span></span>, <span class="n">2023-1-20</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.3802 JPY</span></span>, <span class="n">2023-1-23</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.4003 JPY</span></span>, <span class="n">2023-1-24</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.3793 JPY</span></span>, <span class="n">2023-1-25</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.3732 JPY</span></span>, <span class="n">2023-1-26</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.3926 JPY</span></span>, <span class="n">2023-1-27</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.3790 JPY</span></span>, <span class="n">2023-1-30</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.3863 JPY</span></span>, <span class="n">2023-1-31</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.3783 JPY</span></span>, <span class="n">2023-2-1</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.3826 JPY</span></span>, <span class="n">2023-2-2</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.3896 JPY</span></span>, <span class="n">2023-2-3</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.4188 JPY</span></span>, <span class="n">2023-2-6</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.4199 JPY</span></span>, <span class="n">2023-2-7</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.3831 JPY</span></span>, <span class="n">2023-2-8</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.3958 JPY</span></span>, <span class="n">2023-2-9</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.4056 JPY</span></span>, <span class="n">2023-2-10</span>, <span class="n"><span class="nowrap">1 PHP =</span> <span class="nowrap">2.4102 JPY</span></span>, <span class="n">2023-2 ...

# %%
import requests
import time
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
from selenium.webdriver.common.actions.action_builder import ActionBuilder
from selenium.webdriver.common.actions.mouse_button import MouseButton
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import re
from datetime import date
currentdate = date.today()
current_year = int(currentdate.year)

# getting the user inputs
from_currency = input("Please input your original currency: ").upper()
currencies = ["JPY"]
how_many_years_back = int(input("How many years back do you want to consider the data of? "))
exchange_rates = {}

# open driver
driver = webdriver.Chrome()

# going thru all the exchange rates
for to_currency in currencies:
    # load website
    history = []
    for j in range(0, how_many_years_back+1):
        search_year = int(current_year - j)
        link = f"https://www.exchange-rates.org/exchange-rate-history/{from_currency}-{to_currency}-{search_year}"
        print(link)
        response = requests.get(link)
    
        soup = BeautifulSoup(response.text, 'html.parser')

        data = soup.find_all('tr')
        
        for sflkdjasfjlk in range(0,5):
            data.pop(0)
        remove_this = ['<tr>', '<td>', '<span class="w">', '<span class="n">', '</span>', '</td>', '</tr>', '<span class="nowrap">', '<tr class="odd">', '\n']
        for i in data:
            try:
                string_i = str(i)
                for eww in remove_this:
                    string_i = string_i.replace(eww,"")
    
                # FORMAT THE RAW LINE
                date = string_i[string_i.index(str(search_year))+4:string_i.index(str("1 "+str(from_currency)))]
                rate = string_i[(string_i.index(date)+len(date)):string_i.index(to_currency)+len(to_currency)]
                new_entry = str(date+" | "+ rate)
                history.append(new_entry)
            except:
                pass

    # print(history)
    exchange_rates[to_currency] = history
    print(exchange_rates)
# Out:
# Please input your original currency:  PHP
# How many years back do you want to consider the data of?  0
# https://www.exchange-rates.org/exchange-rate-history/PHP-JPY-2024
# {'JPY': ['2024-1-1 | 1 PHP = 2.5441 JPY', '2024-1-2 | 1 PHP = 2.5568 JPY', '2024-1-3 | 1 PHP = 2.5676 JPY', '2024-1-4 | 1 PHP = 2.6051 JPY', '2024-1-5 | 1 PHP = 2.6058 JPY', '2024-1-8 | 1 PHP = 2.5858 JPY', '2024-1-9 | 1 PHP = 2.5724 JPY', '2024-1-10 | 1 PHP = 2.5936 JPY', '2024-1-11 | 1 PHP = 2.5888 JPY', '2024-1-12 | 1 PHP = 2.5958 JPY', '2024-1-15 | 1 PHP = 2.6163 JPY', '2024-1-16 | 1 PHP = 2.6296 JPY', '2024-1-17 | 1 PHP = 2.6465 JPY', '2024-1-18 | 1 PHP = 2.6536 JPY', '2024-1-19 | 1 PHP = 2.6507 JPY', '2024-1-22 | 1 PHP = 2.6276 JPY', '2024-1-23 | 1 PHP = 2.6294 JPY', '2024-1-24 | 1 PHP = 2.6224 JPY', '2024-1-25 | 1 PHP = 2.6094 JPY', '2024-1-26 | 1 PHP = 2.6311 JPY', '2024-1-29 | 1 PHP = 2.6143 JPY', '2024-1-30 | 1 PHP = 2.6185 JPY', '2024-1-31 | 1 PHP = 2.6095 JPY', '2024-2-1 | 1 PHP = 2.6151 JPY', '2024-2-2 | 1 PHP = 2.6418 JPY', '2024-2-5 | 1 PHP = 2.6369 JPY', '2024-2-6 | 1 PHP = 2.6323 JPY', '2024-2-7 | 1 PHP = 2.6415 JPY', '2024-2-8 | 1 PHP = 2.6666 JPY', '2024-2-9 | 1 PHP = 2.6712 JPY', '2024-2-12 | 1 PHP = 2.6692 JPY', '2024-2-13 | 1 PHP = 2.6823 JPY', '2024-2-14 | 1 PHP = 2.6812 JPY', '2024-2-15 | 1 PHP = 2.6784 JPY', '2024-2-16 | 1 PHP = 2.6840 JPY', '2024-2-19 | 1 PHP = 2.6805 JPY', '2024-2-20 | 1 PHP = 2.6803 JPY', '2024-2-21 | 1 PHP = 2.6883 JPY', '2024-2-22 | 1 PHP = 2.6970 JPY', '2024-2-23 | 1 PHP = 2.6904 JPY', '2024-2-26 | 1 PHP = 2.6883 JPY', '2024-2-27 | 1 PHP = 2.6829 JPY', '2024-2-28 | 1 PHP = 2.6769 JPY', '2024-2-29 | 1 PHP = 2.6720 JPY', '2024-3-1 | 1 PHP = 2.6790 JPY', '2024-3-4 | 1 PHP = 2.6851 JPY', '2024-3-5 | 1 PHP = 2.6773 JPY', '2024-3-6 | 1 PHP = 2.6741 JPY', '2024-3-7 | 1 PHP = 2.6504 JPY', '2024-3-8 | 1 PHP = 2.6487 JPY', '2024-3-11 | 1 PHP = 2.6546 JPY', '2024-3-12 | 1 PHP = 2.6581 JPY', '2024-3-13 | 1 PHP = 2.6670 JPY', '2024-3-14 | 1 PHP = 2.6705 JPY', '2024-3-15 | 1 PHP = 2.6801 JPY', '2024-3-18 | 1 PHP = 2.6784 JPY', '2024-3-19 | 1 PHP = 2.7014 JPY', '2024-3-20 | 1 PHP = 2.6933 JPY', '2024-3-21 | 1 PHP = 2.7060 JPY', '2024-3-22 | 1 PHP = 2.6852 JPY', '2024-3-25 | 1 PHP = 2.6905 JPY', '2024-3-26 | 1 PHP = 2.6926 JPY', '2024-3-27 | 1 PHP = 2.6882 JPY', '2024-3-28 | 1 PHP = 2.6948 JPY', '2024-3-29 | 1 PHP = 2.6947 JPY', '2024-4-1 | 1 PHP = 2.6959 JPY', '2024-4-2 | 1 PHP = 2.6898 JPY', '2024-4-3 | 1 PHP = 2.6856 JPY', '2024-4-4 | 1 PHP = 2.6702 JPY', '2024-4-5 | 1 PHP = 2.6790 JPY', '2024-4-8 | 1 PHP = 2.6858 JPY', '2024-4-9 | 1 PHP = 2.6956 JPY', '2024-4-10 | 1 PHP = 2.7034 JPY', '2024-4-11 | 1 PHP = 2.7124 JPY', '2024-4-12 | 1 PHP = 2.7093 JPY', '2024-4-15 | 1 PHP = 2.7058 JPY', '2024-4-16 | 1 PHP = 2.7116 JPY', '2024-4-17 | 1 PHP = 2.6960 JPY', '2024-4-18 | 1 PHP = 2.6992 JPY', '2024-4-19 | 1 PHP = 2.6857 JPY', '2024-4-22 | 1 PHP = 2.6917 JPY', '2024-4-23 | 1 PHP = 2.6947 JPY', '2024-4-24 | 1 PHP = 2.6814 JPY', '2024-4-25 | 1 PHP = 2.6899 JPY', '2024-4-26 | 1 PHP = 2.7469 JPY', '2024-4-29 | 1 PHP = 2.7093 JPY', '2024-4-30 | 1 PHP = 2.7265 JPY', '2024-5-1 | 1 PHP = 2.6904 JPY', '2024-5-2 | 1 PHP = 2.6692 JPY', '2024-5-3 | 1 PHP = 2.6822 JPY', '2024-5-6 | 1 PHP = 2.6860 JPY', '2024-5-7 | 1 PHP = 2.7024 JPY', '2024-5-8 | 1 PHP = 2.7095 JPY', '2024-5-9 | 1 PHP = 2.7103 JPY', '2024-5-10 | 1 PHP = 2.7062 JPY', '2024-5-13 | 1 PHP = 2.6997 JPY', '2024-5-14 | 1 PHP = 2.7081 JPY', '2024-5-15 | 1 PHP = 2.6870 JPY', '2024-5-16 | 1 PHP = 2.7029 JPY', '2024-5-17 | 1 PHP = 2.6968 JPY', '2024-5-20 | 1 PHP = 2.6883 JPY', '2024-5-21 | 1 PHP = 2.6844 JPY', '2024-5-22 | 1 PHP = 2.6984 JPY', '2024-5-23 | 1 PHP = 2.6927 JPY', '2024-5-24 | 1 PHP = 2.6968 JPY', '2024-5-27 | 1 PHP = 2.6997 JPY', '2024-5-28 | 1 PHP = 2.7086 JPY', '2024-5-29 | 1 PHP = 2.6912 JPY', '2024-5-30 | 1 PHP = 2.6805 JPY', '2024-5-31 | 1 PHP = 2.6873 JPY', '2024-6-3 | 1 PHP = 2.6617 JPY', '2024-6-4 | 1 PHP = 2.6346 JPY', '2024-6-5 | 1 PHP = 2.6580 JPY', '2024-6-6 | 1 PHP = 2.6535 JPY', '2024-6-7 | 1 PHP = 2.6664 JPY', '2024-6-10 | 1 PHP = 2.6673 JPY', '2024-6-11 | 1 PHP = 2.6719 JPY', '2024-6-12 | 1 PHP = 2.6799 JPY', '2024-6-13 | 1 PHP ...

# %%
import requests
import time
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
from selenium.webdriver.common.actions.action_builder import ActionBuilder
from selenium.webdriver.common.actions.mouse_button import MouseButton
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import re
from datetime import date
currentdate = date.today()
current_year = int(currentdate.year)

# getting the user inputs
from_currency = input("Please input your original currency: ").upper()
currencies = ["EUR", "USD", "GBP", "CAD", "AUD", "ALL", "DZD", "AOA", "AMD", "AZN", "BSD", "BHD", "BDT", 
    "BBD", "BYN", "BZD", "BMD", "BOB", "BAM", "BWP", "BRL", "GBP", "BND", "BGN", "BIF", "KHR", 
    "CAD", "CVE", "KYD", "XOF", "XAF", "XPF", "CLP", "CNY", "COP", "CRC", "HRK", "CUP", "CZK", 
    "DKK", "DJF", "DOP", "XCD", "EGP", "ETB", "FJD", "GMD", "GEL", "GHS", "GTQ", "GNF", 
    "HTG", "HNL", "HKD", "ISK", "INR", "IDR", "IRR", "IQD", "ILS", "JMD", "JPY", "JOD", "KZT", 
    "KES", "KRW", "KWD", "KGS", "LAK", "LBP", "LSL", "LYD", "MOP", "MKD", "MWK", "MYR", "MUR", 
    "MXN", "MDL", "MAD", "MMK", "NAD", "NPR", "ANG", "NZD", "NIO", "NGN", "NOK", "OMR", "PKR", 
    "PAB", "PYG", "PEN", "PLN", "PHP", "QAR", "RON", "RUB", "RWF", "SAR", "RSD", "SCR", "SGD", 
    "SOS", "ZAR", "LKR", "SDG", "SZL", "SEK", "CHF", "SYP", "TWD", "TZS", "THB", "TTD", "TND", 
    "TRY", "TMT", "UGX", "UAH", "AED", "UYU", "USD", "UZS", "VES", "VND", "YER", "ZMW"]
how_many_years_back = int(input("How many years back do you want to consider the data of? "))
exchange_rates = {}

# open driver
driver = webdriver.Chrome()

# going thru all the exchange rates
for to_currency in currencies:
    # load website
    history = []
    if to_currency != from_currency:
        for j in range(0, how_many_years_back+1):
            search_year = int(current_year - j)
            link = f"https://www.exchange-rates.org/exchange-rate-history/{from_currency}-{to_currency}-{search_year}"
            # print(link)
            response = requests.get(link)
        
            soup = BeautifulSoup(response.text, 'html.parser')
    
            data = soup.find_all('tr')
            
            for sflkdjasfjlk in range(0,5):
                data.pop(0)
            remove_this = ['<tr>', '<td>', '<span class="w">', '<span class="n">', '</span>', '</td>', '</tr>', '<span class="nowrap">', '<tr class="odd">', '\n']
            for i in data:
                try:
                    string_i = str(i)
                    for eww in remove_this:
                        string_i = string_i.replace(eww,"")
    
                    # REMOVED EVERTHING EXCEPT THE <A>
                    if "</a>" in string_i:
                        string_i = string_i.replace("</a>", "")
                        string_i = string_i[string_i.index(">")+1:]
                        i_hate_this = string_i[string_i.index("<"):string_i.index(">")+1]
                        string_i = string_i.replace(i_hate_this,"")
                    
                    # FORMAT THE RAW LINE
                    date = string_i[string_i.index(str(search_year))+4:string_i.index(str("1 "+str(from_currency)))]
                    rate = string_i[(string_i.index(date)+len(date)):string_i.index(to_currency)+len(to_currency)]
                    new_entry = str(date+" | "+ rate)
                    history.append(new_entry)
                except:
                    pass

    # print(history)
    exchange_rates[to_currency] = history
    print(exchange_rates)
# Out:
# Please input your original currency:  php
# How many years back do you want to consider the data of?  1
# https://www.exchange-rates.org/exchange-rate-history/PHP-JPY-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-JPY-2023
# {'JPY': ['2024-1-1 | 1 PHP = 2.5441 JPY', '2024-1-2 | 1 PHP = 2.5568 JPY', '2024-1-3 | 1 PHP = 2.5676 JPY', '2024-1-4 | 1 PHP = 2.6051 JPY', '2024-1-5 | 1 PHP = 2.6058 JPY', '2024-1-8 | 1 PHP = 2.5858 JPY', '2024-1-9 | 1 PHP = 2.5724 JPY', '2024-1-10 | 1 PHP = 2.5936 JPY', '2024-1-11 | 1 PHP = 2.5888 JPY', '2024-1-12 | 1 PHP = 2.5958 JPY', '2024-1-15 | 1 PHP = 2.6163 JPY', '2024-1-16 | 1 PHP = 2.6296 JPY', '2024-1-17 | 1 PHP = 2.6465 JPY', '2024-1-18 | 1 PHP = 2.6536 JPY', '2024-1-19 | 1 PHP = 2.6507 JPY', '2024-1-22 | 1 PHP = 2.6276 JPY', '2024-1-23 | 1 PHP = 2.6294 JPY', '2024-1-24 | 1 PHP = 2.6224 JPY', '2024-1-25 | 1 PHP = 2.6094 JPY', '2024-1-26 | 1 PHP = 2.6311 JPY', '2024-1-29 | 1 PHP = 2.6143 JPY', '2024-1-30 | 1 PHP = 2.6185 JPY', '2024-1-31 | 1 PHP = 2.6095 JPY', '2024-2-1 | 1 PHP = 2.6151 JPY', '2024-2-2 | 1 PHP = 2.6418 JPY', '2024-2-5 | 1 PHP = 2.6369 JPY', '2024-2-6 | 1 PHP = 2.6323 JPY', '2024-2-7 | 1 PHP = 2.6415 JPY', '2024-2-8 | 1 PHP = 2.6666 JPY', '2024-2-9 | 1 PHP = 2.6712 JPY', '2024-2-12 | 1 PHP = 2.6692 JPY', '2024-2-13 | 1 PHP = 2.6823 JPY', '2024-2-14 | 1 PHP = 2.6812 JPY', '2024-2-15 | 1 PHP = 2.6784 JPY', '2024-2-16 | 1 PHP = 2.6840 JPY', '2024-2-19 | 1 PHP = 2.6805 JPY', '2024-2-20 | 1 PHP = 2.6803 JPY', '2024-2-21 | 1 PHP = 2.6883 JPY', '2024-2-22 | 1 PHP = 2.6970 JPY', '2024-2-23 | 1 PHP = 2.6904 JPY', '2024-2-26 | 1 PHP = 2.6883 JPY', '2024-2-27 | 1 PHP = 2.6829 JPY', '2024-2-28 | 1 PHP = 2.6769 JPY', '2024-2-29 | 1 PHP = 2.6720 JPY', '2024-3-1 | 1 PHP = 2.6790 JPY', '2024-3-4 | 1 PHP = 2.6851 JPY', '2024-3-5 | 1 PHP = 2.6773 JPY', '2024-3-6 | 1 PHP = 2.6741 JPY', '2024-3-7 | 1 PHP = 2.6504 JPY', '2024-3-8 | 1 PHP = 2.6487 JPY', '2024-3-11 | 1 PHP = 2.6546 JPY', '2024-3-12 | 1 PHP = 2.6581 JPY', '2024-3-13 | 1 PHP = 2.6670 JPY', '2024-3-14 | 1 PHP = 2.6705 JPY', '2024-3-15 | 1 PHP = 2.6801 JPY', '2024-3-18 | 1 PHP = 2.6784 JPY', '2024-3-19 | 1 PHP = 2.7014 JPY', '2024-3-20 | 1 PHP = 2.6933 JPY', '2024-3-21 | 1 PHP = 2.7060 JPY', '2024-3-22 | 1 PHP = 2.6852 JPY', '2024-3-25 | 1 PHP = 2.6905 JPY', '2024-3-26 | 1 PHP = 2.6926 JPY', '2024-3-27 | 1 PHP = 2.6882 JPY', '2024-3-28 | 1 PHP = 2.6948 JPY', '2024-3-29 | 1 PHP = 2.6947 JPY', '2024-4-1 | 1 PHP = 2.6959 JPY', '2024-4-2 | 1 PHP = 2.6898 JPY', '2024-4-3 | 1 PHP = 2.6856 JPY', '2024-4-4 | 1 PHP = 2.6702 JPY', '2024-4-5 | 1 PHP = 2.6790 JPY', '2024-4-8 | 1 PHP = 2.6858 JPY', '2024-4-9 | 1 PHP = 2.6956 JPY', '2024-4-10 | 1 PHP = 2.7034 JPY', '2024-4-11 | 1 PHP = 2.7124 JPY', '2024-4-12 | 1 PHP = 2.7093 JPY', '2024-4-15 | 1 PHP = 2.7058 JPY', '2024-4-16 | 1 PHP = 2.7116 JPY', '2024-4-17 | 1 PHP = 2.6960 JPY', '2024-4-18 | 1 PHP = 2.6992 JPY', '2024-4-19 | 1 PHP = 2.6857 JPY', '2024-4-22 | 1 PHP = 2.6917 JPY', '2024-4-23 | 1 PHP = 2.6947 JPY', '2024-4-24 | 1 PHP = 2.6814 JPY', '2024-4-25 | 1 PHP = 2.6899 JPY', '2024-4-26 | 1 PHP = 2.7469 JPY', '2024-4-29 | 1 PHP = 2.7093 JPY', '2024-4-30 | 1 PHP = 2.7265 JPY', '2024-5-1 | 1 PHP = 2.6904 JPY', '2024-5-2 | 1 PHP = 2.6692 JPY', '2024-5-3 | 1 PHP = 2.6822 JPY', '2024-5-6 | 1 PHP = 2.6860 JPY', '2024-5-7 | 1 PHP = 2.7024 JPY', '2024-5-8 | 1 PHP = 2.7095 JPY', '2024-5-9 | 1 PHP = 2.7103 JPY', '2024-5-10 | 1 PHP = 2.7062 JPY', '2024-5-13 | 1 PHP = 2.6997 JPY', '2024-5-14 | 1 PHP = 2.7081 JPY', '2024-5-15 | 1 PHP = 2.6870 JPY', '2024-5-16 | 1 PHP = 2.7029 JPY', '2024-5-17 | 1 PHP = 2.6968 JPY', '2024-5-20 | 1 PHP = 2.6883 JPY', '2024-5-21 | 1 PHP = 2.6844 JPY', '2024-5-22 | 1 PHP = 2.6984 JPY', '2024-5-23 | 1 PHP = 2.6927 JPY', '2024-5-24 | 1 PHP = 2.6968 JPY', '2024-5-27 | 1 PHP = 2.6997 JPY', '2024-5-28 | 1 PHP = 2.7086 JPY', '2024-5-29 | 1 PHP = 2.6912 JPY', '2024-5-30 | 1 PHP = 2.6805 JPY', '2024-5-31 | 1 PHP = 2.6873 JPY', '2024-6-3 | 1 PHP = 2.6617 JPY', '2024-6-4 | 1 PHP = 2.6346 JPY', '2024-6-5 | 1 PHP = 2.6580 JPY', '2024-6-6 | 1 PHP = 2.6535 JPY', '2024-6-7 | 1 PHP = 2.6664 JPY', '2024-6-10 | 1 PHP = 2.6673 JPY', '2024-6-11 | 1 PHP = 2.6719 JPY', '2024-6-12 | 1 PHP = 2.6799 JPY', '2024-6-13 | 1 PHP ...
# https://www.exchange-rates.org/exchange-rate-history/PHP-USD-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-USD-2023
# {'JPY': ['2024-1-1 | 1 PHP = 2.5441 JPY', '2024-1-2 | 1 PHP = 2.5568 JPY', '2024-1-3 | 1 PHP = 2.5676 JPY', '2024-1-4 | 1 PHP = 2.6051 JPY', '2024-1-5 | 1 PHP = 2.6058 JPY', '2024-1-8 | 1 PHP = 2.5858 JPY', '2024-1-9 | 1 PHP = 2.5724 JPY', '2024-1-10 | 1 PHP = 2.5936 JPY', '2024-1-11 | 1 PHP = 2.5888 JPY', '2024-1-12 | 1 PHP = 2.5958 JPY', '2024-1-15 | 1 PHP = 2.6163 JPY', '2024-1-16 | 1 PHP = 2.6296 JPY', '2024-1-17 | 1 PHP = 2.6465 JPY', '2024-1-18 | 1 PHP = 2.6536 JPY', '2024-1-19 | 1 PHP = 2.6507 JPY', '2024-1-22 | 1 PHP = 2.6276 JPY', '2024-1-23 | 1 PHP = 2.6294 JPY', '2024-1-24 | 1 PHP = 2.6224 JPY', '2024-1-25 | 1 PHP = 2.6094 JPY', '2024-1-26 | 1 PHP = 2.6311 JPY', '2024-1-29 | 1 PHP = 2.6143 JPY', '2024-1-30 | 1 PHP = 2.6185 JPY', '2024-1-31 | 1 PHP = 2.6095 JPY', '2024-2-1 | 1 PHP = 2.6151 JPY', '2024-2-2 | 1 PHP = 2.6418 JPY', '2024-2-5 | 1 PHP = 2.6369 JPY', '2024-2-6 | 1 PHP = 2.6323 JPY', '2024-2-7 | 1 PHP = 2.6415 JPY', '2024-2-8 | 1 PHP = 2.6666 JPY', '2024-2-9 | 1 PHP = 2.6712 JPY', '2024-2-12 | 1 PHP = 2.6692 JPY', '2024-2-13 | 1 PHP = 2.6823 JPY', '2024-2-14 | 1 PHP = 2.6812 JPY', '2024-2-15 | 1 PHP = 2.6784 JPY', '2024-2-16 | 1 PHP = 2.6840 JPY', '2024-2-19 | 1 PHP = 2.6805 JPY', '2024-2-20 | 1 PHP = 2.6803 JPY', '2024-2-21 | 1 PHP = 2.6883 JPY', '2024-2-22 | 1 PHP = 2.6970 JPY', '2024-2-23 | 1 PHP = 2.6904 JPY', '2024-2-26 | 1 PHP = 2.6883 JPY', '2024-2-27 | 1 PHP = 2.6829 JPY', '2024-2-28 | 1 PHP = 2.6769 JPY', '2024-2-29 | 1 PHP = 2.6720 JPY', '2024-3-1 | 1 PHP = 2.6790 JPY', '2024-3-4 | 1 PHP = 2.6851 JPY', '2024-3-5 | 1 PHP = 2.6773 JPY', '2024-3-6 | 1 PHP = 2.6741 JPY', '2024-3-7 | 1 PHP = 2.6504 JPY', '2024-3-8 | 1 PHP = 2.6487 JPY', '2024-3-11 | 1 PHP = 2.6546 JPY', '2024-3-12 | 1 PHP = 2.6581 JPY', '2024-3-13 | 1 PHP = 2.6670 JPY', '2024-3-14 | 1 PHP = 2.6705 JPY', '2024-3-15 | 1 PHP = 2.6801 JPY', '2024-3-18 | 1 PHP = 2.6784 JPY', '2024-3-19 | 1 PHP = 2.7014 JPY', '2024-3-20 | 1 PHP = 2.6933 JPY', '2024-3-21 | 1 PHP = 2.7060 JPY', '2024-3-22 | 1 PHP = 2.6852 JPY', '2024-3-25 | 1 PHP = 2.6905 JPY', '2024-3-26 | 1 PHP = 2.6926 JPY', '2024-3-27 | 1 PHP = 2.6882 JPY', '2024-3-28 | 1 PHP = 2.6948 JPY', '2024-3-29 | 1 PHP = 2.6947 JPY', '2024-4-1 | 1 PHP = 2.6959 JPY', '2024-4-2 | 1 PHP = 2.6898 JPY', '2024-4-3 | 1 PHP = 2.6856 JPY', '2024-4-4 | 1 PHP = 2.6702 JPY', '2024-4-5 | 1 PHP = 2.6790 JPY', '2024-4-8 | 1 PHP = 2.6858 JPY', '2024-4-9 | 1 PHP = 2.6956 JPY', '2024-4-10 | 1 PHP = 2.7034 JPY', '2024-4-11 | 1 PHP = 2.7124 JPY', '2024-4-12 | 1 PHP = 2.7093 JPY', '2024-4-15 | 1 PHP = 2.7058 JPY', '2024-4-16 | 1 PHP = 2.7116 JPY', '2024-4-17 | 1 PHP = 2.6960 JPY', '2024-4-18 | 1 PHP = 2.6992 JPY', '2024-4-19 | 1 PHP = 2.6857 JPY', '2024-4-22 | 1 PHP = 2.6917 JPY', '2024-4-23 | 1 PHP = 2.6947 JPY', '2024-4-24 | 1 PHP = 2.6814 JPY', '2024-4-25 | 1 PHP = 2.6899 JPY', '2024-4-26 | 1 PHP = 2.7469 JPY', '2024-4-29 | 1 PHP = 2.7093 JPY', '2024-4-30 | 1 PHP = 2.7265 JPY', '2024-5-1 | 1 PHP = 2.6904 JPY', '2024-5-2 | 1 PHP = 2.6692 JPY', '2024-5-3 | 1 PHP = 2.6822 JPY', '2024-5-6 | 1 PHP = 2.6860 JPY', '2024-5-7 | 1 PHP = 2.7024 JPY', '2024-5-8 | 1 PHP = 2.7095 JPY', '2024-5-9 | 1 PHP = 2.7103 JPY', '2024-5-10 | 1 PHP = 2.7062 JPY', '2024-5-13 | 1 PHP = 2.6997 JPY', '2024-5-14 | 1 PHP = 2.7081 JPY', '2024-5-15 | 1 PHP = 2.6870 JPY', '2024-5-16 | 1 PHP = 2.7029 JPY', '2024-5-17 | 1 PHP = 2.6968 JPY', '2024-5-20 | 1 PHP = 2.6883 JPY', '2024-5-21 | 1 PHP = 2.6844 JPY', '2024-5-22 | 1 PHP = 2.6984 JPY', '2024-5-23 | 1 PHP = 2.6927 JPY', '2024-5-24 | 1 PHP = 2.6968 JPY', '2024-5-27 | 1 PHP = 2.6997 JPY', '2024-5-28 | 1 PHP = 2.7086 JPY', '2024-5-29 | 1 PHP = 2.6912 JPY', '2024-5-30 | 1 PHP = 2.6805 JPY', '2024-5-31 | 1 PHP = 2.6873 JPY', '2024-6-3 | 1 PHP = 2.6617 JPY', '2024-6-4 | 1 PHP = 2.6346 JPY', '2024-6-5 | 1 PHP = 2.6580 JPY', '2024-6-6 | 1 PHP = 2.6535 JPY', '2024-6-7 | 1 PHP = 2.6664 JPY', '2024-6-10 | 1 PHP = 2.6673 JPY', '2024-6-11 | 1 PHP = 2.6719 JPY', '2024-6-12 | 1 PHP = 2.6799 JPY', '2024-6-13 | 1 PHP ...
